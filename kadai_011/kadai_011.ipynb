# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for solar_systems in array:
    print(solar_systems)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
array = ["水","金","地","火","木","土","天","海","冥"]

#カウンタ変数を用意する
i = 0

#配列の中身を全てとりだしたら、繰り返し処理を終了する。
while i < len(array) :
   print(array[i])

   i = i+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
